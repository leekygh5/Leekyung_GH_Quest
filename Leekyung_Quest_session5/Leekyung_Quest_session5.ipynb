# %% [markdown]
# # session05 Quest _크롤링&sqlite3 저장

# %%
from bs4 import BeautifulSoup as bs
import lxml

# %%
from selenium import webdriver 
import time
import requests
from selenium.webdriver.common.keys import Keys

# %%
from selenium import webdriver

day_num = [0, 127, 234, 336, 444, 551, 648] #일주일 간 날짜에 해당하는 번호

path = 'C:\\Users\\LEE KO\\chromedriver.exe'

driver = webdriver.Chrome(path)

driver.get("http://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do?loadEnd=0&searchType=search&sSearchFrom=2019-03-29&sSearchTo=2019-04-05&sMultiMovieYn=&sRepNationCd=&sWideAreaCd=")

driver.implicitly_wait(4) 

#for문으로 일주일 간 날짜 각각의 영화 순위 50위까지 나오게 하기
for i in range(7):
    for j in range(4):
        driver.find_element_by_id("btn_"+ str(day_num[i])).click() 
        driver.implicitly_wait(2)

daily_boxoffice_html = driver.page_source

#창 닫기
driver.quit()

# %% [markdown]
# #### 이 아래 부분은 반복문이나 객체 형태를 지정해서 해결할 수 있을 거 같은데... 잘 안돼서 쓰면서 풀었습니다:(

# %%
#parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

#for문으로 새로운 변수 생성하면서 html로 할당하려고 했으나 아래처럼은 안되고 방법 아직 못찾음..
#for i in range(7): 
    #daily_boxoffice + str(i) = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_"+ str(day_num[i])})
    #movie_list+ str(i) = (daily_boxoffice + str(i)).find_all("tr")
    
    
parsed_daily_boxoffice_html = bs(daily_boxoffice_html, 'html.parser')

daily_boxoffice_0 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_0"})
daily_boxoffice_1 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_127"})
daily_boxoffice_2 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_234"})
daily_boxoffice_3 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_336"})
daily_boxoffice_4 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_444"})
daily_boxoffice_5 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_551"})
daily_boxoffice_6 = parsed_daily_boxoffice_html.find("tbody", {"id":"tbody_648"})

#마찬가지로 아래 방법은 안돼서 우선 쓰기로
#for i in range(7):
#    movie_list+str(i) = daily_boxoffice_+str(i).find_all("tr")

movie_list_0=daily_boxoffice_0.find_all("tr")
movie_list_1=daily_boxoffice_1.find_all("tr")
movie_list_2=daily_boxoffice_2.find_all("tr")
movie_list_3=daily_boxoffice_3.find_all("tr")
movie_list_4=daily_boxoffice_4.find_all("tr")
movie_list_5=daily_boxoffice_5.find_all("tr")
movie_list_6=daily_boxoffice_6.find_all("tr")

# %%
# 7일 각각 50위 영화에 대한 dataframe 만들기
import pandas as pd

daily_movies_0= {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list_0:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies_0['영화명'].append(title_rank[:-5].strip())
    daily_movies_0['순위 변동'].append(title_rank[-4:].strip())
    daily_movies_0['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_0['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_0['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_0['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_0['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_0['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_0['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    
daily_movies_1= {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list_1:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies_1['영화명'].append(title_rank[:-5].strip())
    daily_movies_1['순위 변동'].append(title_rank[-4:].strip())
    daily_movies_1['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_1['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_1['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_1['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_1['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_1['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_1['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
daily_movies_2= {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list_2:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies_2['영화명'].append(title_rank[:-5].strip())
    daily_movies_2['순위 변동'].append(title_rank[-4:].strip())
    daily_movies_2['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_2['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_2['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_2['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_2['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_2['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_2['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
daily_movies_3= {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list_3:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies_3['영화명'].append(title_rank[:-5].strip())
    daily_movies_3['순위 변동'].append(title_rank[-4:].strip())
    daily_movies_3['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_3['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_3['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_3['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_3['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_3['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_3['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
daily_movies_4= {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list_4:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies_4['영화명'].append(title_rank[:-5].strip())
    daily_movies_4['순위 변동'].append(title_rank[-4:].strip())
    daily_movies_4['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_4['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_4['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_4['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_4['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_4['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_4['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
daily_movies_5= {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list_5:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies_5['영화명'].append(title_rank[:-5].strip())
    daily_movies_5['순위 변동'].append(title_rank[-4:].strip())
    daily_movies_5['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_5['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_5['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_5['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_5['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_5['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_5['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
 
daily_movies_6= {'영화명' : [],
'순위 변동' : [],
'개봉일' : [],
'매출액' : [],
'매출액점유율' : [],
'관객수' : [],
'누적관객수' : [],
'스크린수' : [],
'상영횟수' : []}

for movie in movie_list_6:
    title_rank = movie.find("td").find_next_sibling("td").text
    daily_movies_6['영화명'].append(title_rank[:-5].strip())
    daily_movies_6['순위 변동'].append(title_rank[-4:].strip())
    daily_movies_6['개봉일'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_6['매출액'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_6['매출액점유율'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_6['관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_6['누적관객수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_6['스크린수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())
    daily_movies_6['상영횟수'].append(movie.find("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").find_next_sibling("td").text.strip())

# %%
daily_boxoffice_0 = pd.DataFrame(daily_movies_0) 
daily_boxoffice_1 = pd.DataFrame(daily_movies_1)
daily_boxoffice_2 = pd.DataFrame(daily_movies_2)
daily_boxoffice_3 = pd.DataFrame(daily_movies_3)
daily_boxoffice_4 = pd.DataFrame(daily_movies_4)
daily_boxoffice_5 = pd.DataFrame(daily_movies_5)
daily_boxoffice_6 = pd.DataFrame(daily_movies_6)


#순위 바꾸기
def change_rank(rank):
    if rank == "동일":
        rank = 0
    elif rank[-2:] == "하락":
        rank = int(rank[:-2]) * -1
    elif rank[-2:] == "상승":
        rank = int(rank[:-2]) * 1
    return rank

daily_boxoffice_0['순위 변동'] = daily_boxoffice_0['순위 변동'].map(lambda x: change_rank(x))
daily_boxoffice_1['순위 변동'] = daily_boxoffice_1['순위 변동'].map(lambda x: change_rank(x))
daily_boxoffice_2['순위 변동'] = daily_boxoffice_2['순위 변동'].map(lambda x: change_rank(x))
daily_boxoffice_3['순위 변동'] = daily_boxoffice_3['순위 변동'].map(lambda x: change_rank(x))
daily_boxoffice_4['순위 변동'] = daily_boxoffice_4['순위 변동'].map(lambda x: change_rank(x))
daily_boxoffice_5['순위 변동'] = daily_boxoffice_5['순위 변동'].map(lambda x: change_rank(x))
daily_boxoffice_6['순위 변동'] = daily_boxoffice_6['순위 변동'].map(lambda x: change_rank(x))

daily_boxoffice_0.head()
# Out:
#        영화명 순위 변동         개봉일          매출액 매출액점유율     관객수      누적관객수   스크린수  \
# 0      샤잠!     0  2019-04-03  642,396,652  26.3%  70,675    216,478  1,148
# 1       생일     0  2019-04-03  495,485,368  20.3%  57,316    156,761    862
# 2        돈     0  2019-03-20  423,838,434  17.3%  47,658  2,934,975    709
# 3       어스     0  2019-03-27  434,078,128  17.7%  47,594  1,181,512    658
# 4  장난스런 키스     0  2019-03-27  142,786,590   5.8%  16,465    246,560    383
#
#     상영횟수
# 0  5,152
# 1  3,575
# 2  2,719
# 3  2,293
# 4    701

# %%
#확인용
daily_boxoffice_6.head()
# Out:
#        영화명 순위 변동         개봉일            매출액 매출액점유율      관객수      누적관객수   스크린수  \
# 0       어스     0  2019-03-27  2,528,527,731  36.3%  275,451    717,812  1,132
# 1        돈     0  2019-03-20  2,295,707,570  32.9%  256,035  2,441,353  1,157
# 2       덤보     2  2019-03-27    660,853,559   9.5%   78,695    132,249    761
# 3    캡틴 마블    -1  2019-03-06    675,853,110   9.7%   77,530  5,473,769    619
# 4  장난스런 키스    -1  2019-03-27    383,004,241   5.5%   46,032    121,934    482
#
#     상영횟수
# 0  5,487
# 1  5,736
# 2  2,200
# 3  1,895
# 4  1,186

# %% [markdown]
# # SQLITE로 저장

# %%
import sqlite3

con = sqlite3.connect("daily_boxoffice.db")

#con.execute("CREATE TABLE IF NOT EXISTS boxoffice(title text, rank int, open text, earning int, earning_share text, audiences int, total_audiences int, num_screen int, num_play int)")

# %%
daily_boxoffice_0.to_sql("boxoffice_0", con, chunksize=1000, if_exists='replace', index=False)
daily_boxoffice_1.to_sql("boxoffice_1", con, chunksize=1000, if_exists='replace', index=False)
daily_boxoffice_2.to_sql("boxoffice_2", con, chunksize=1000, if_exists='replace', index=False)
daily_boxoffice_3.to_sql("boxoffice_3", con, chunksize=1000, if_exists='replace', index=False)
daily_boxoffice_4.to_sql("boxoffice_4", con, chunksize=1000, if_exists='replace', index=False)
daily_boxoffice_5.to_sql("boxoffice_5", con, chunksize=1000, if_exists='replace', index=False)
daily_boxoffice_6.to_sql("boxoffice_6", con, chunksize=1000, if_exists='replace', index=False)

# %%
con.commit()

con.close()
